# %% [markdown]
# # Module: Supervised Learning

# %% [markdown]
# # Section: Decision Tree

# %% [markdown]
# ## <font color='#4073FF'>Project Solution: Credit Card Default Prediction</font>

# %% [markdown]
# ### <font color='#14AAF5'>Identify why customers are more inclined to delay payments as this could be crucial in developing new and more effective schemes.</font>

# %% [markdown]
# ### Project Brief:
#
# To default is to fail to make a payment on a debt by the due date. If this happens with a credit card, creditors might raise interest rates to the default (or penalty rate) or decrease the line of credit. In case of serious delinquency, the card issuer can even take legal action to enforce payment or to garnish wages. A default is a negative payment marker that arises as a result of unpaid arrears on the customer’s credit file. When a default is issued it usually means that the lender no longer sees the borrower as a customer, but instead sees them as a debtor. Credit card companies often give a few months before an account goes into default.
#
# This case study is about a credit card company from Taiwan which has a large customer base. The number of company’s customers who default credit card payments is a very small portion of the total customer base. Majority of these customers pay the remaining amount on time. The company is intending to understand their consumer base due to rapidly increasing number of defaults occurring over time. They need to develop some schemes and policies that they can offer their customers to encourage them to keep their credit scores high and improve their financial habits, but to do that the company first needs to identify why the customers are more inclined to delay payments as this could be crucial in developing new and more effective schemes.

# %% [markdown]
# The questions we might want to answer-
#
# - How does the probability of default payment vary by categories of different demographic variables?
#
# - Which variables are the strongest predictors of default payment?

# %% [markdown]
# ### 1. Dataset
#
#
# - ID: ID of each client
# - LIMIT_BAL: Amount of given credit in NT dollars (includes individual and family/supplementary credit
# - SEX: Gender (1=male, 2=female)
# - EDUCATION: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)
# - MARRIAGE: Marital status (1=married, 2=single, 3=others)
# - AGE: Age in years
# - PAY_0: Repayment status in September, 2005 (-1=pay duly, 1=payment delay for one month, 2=payment delay for two months,             8=payment delay for eight months, 9=payment delay for nine months and above)
# - PAY_2: Repayment status in August, 2005 (scale same as above)
# - PAY_3: Repayment status in July, 2005 (scale same as above)
# - PAY_4: Repayment status in June, 2005 (scale same as above)
# - PAY_5: Repayment status in May, 2005 (scale same as above)
# - PAY_6: Repayment status in April, 2005 (scale same as above)
# - BILL_AMT1: Amount of bill statement in September, 2005 (NT dollar)
# - BILL_AMT2: Amount of bill statement in August, 2005 (NT dollar)
# - BILL_AMT3: Amount of bill statement in July, 2005 (NT dollar)
# - BILL_AMT4: Amount of bill statement in June, 2005 (NT dollar)
# - BILL_AMT5: Amount of bill statement in May, 2005 (NT dollar)
# - BILL_AMT6: Amount of bill statement in April, 2005 (NT dollar)
# - PAY_AMT1: Amount of previous payment in September, 2005 (NT dollar)
# - PAY_AMT2: Amount of previous payment in August, 2005 (NT dollar)
# - PAY_AMT3: Amount of previous payment in July, 2005 (NT dollar)
# - PAY_AMT4: Amount of previous payment in June, 2005 (NT dollar)
# - PAY_AMT5: Amount of previous payment in May, 2005 (NT dollar)
# - PAY_AMT6: Amount of previous payment in April, 2005 (NT dollar)
# - default.payment.next.month: Default payment (1=yes, 0=no)

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# %% [markdown]
# ### 2.  Data collection and exploration

# %%
# Loading the data
df=pd.read_csv("Taiwan_Credit_Card.csv")
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
print(df.shape)
# Out:
# (30000, 25)

# %%
#checking for column info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
# Descriptive statistics
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
# Descriptive statistics for defaulters

# Replacing the name of column to avoid future mishaps
df.rename(columns={
    'default.payment.next.month':'default_next_month'
},inplace=True)

df[df['default_next_month']==1].describe()
# Out:
#                  ID      LIMIT_BAL          SEX    EDUCATION     MARRIAGE  \
# count   6636.000000    6636.000000  6636.000000  6636.000000  6636.000000
# mean   14773.781947  130109.656420     1.567058     1.894665     1.528029
# std     8571.616622  115378.540571     0.495520     0.728096     0.525433
# min        1.000000   10000.000000     1.000000     1.000000     0.000000
# 25%     7408.500000   50000.000000     1.000000     1.000000     1.000000
# 50%    14758.500000   90000.000000     2.000000     2.000000     2.000000
# 75%    21831.750000  200000.000000     2.000000     2.000000     2.000000
# max    30000.000000  740000.000000     2.000000     6.000000     3.000000
#
#                AGE        PAY_0        PAY_2        PAY_3        PAY_4  ...  \
# count  6636.000000  6636.000000  6636.000000  6636.000000  6636.000000  ...
# mean     35.725738     0.668174     0.458258     0.362116     0.254521  ...
# ...

# %% [markdown]
# ### 3. Data Cleaning

# %%
# No duplicates found
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# ID                    0
# LIMIT_BAL             0
# SEX                   0
# EDUCATION             0
# MARRIAGE              0
# AGE                   0
# PAY_0                 0
# PAY_2                 0
# PAY_3                 0
# PAY_4                 0
# PAY_5                 0
# PAY_6                 0
# BILL_AMT1             0
# BILL_AMT2             0
# BILL_AMT3             0
# BILL_AMT4             0
# BILL_AMT5             0
# BILL_AMT6             0
# PAY_AMT1              0
# PAY_AMT2              0
# PAY_AMT3              0
# PAY_AMT4              0
# PAY_AMT5              0
# PAY_AMT6              0
# default_next_month    0
# dtype: int64

# %%
# Skewness
df.skew()
# Out:
# ID                     0.000000
# LIMIT_BAL              0.992867
# SEX                   -0.424183
# EDUCATION              0.970972
# MARRIAGE              -0.018742
# AGE                    0.732246
# PAY_0                  0.731975
# PAY_2                  0.790565
# PAY_3                  0.840682
# PAY_4                  0.999629
# PAY_5                  1.008197
# PAY_6                  0.948029
# BILL_AMT1              2.663861
# BILL_AMT2              2.705221
# BILL_AMT3              3.087830
# BILL_AMT4              2.821965
# BILL_AMT5              2.876380
# BILL_AMT6              2.846645
# PAY_AMT1              14.668364
# PAY_AMT2              30.453817
# PAY_AMT3              17.216635
# PAY_AMT4              12.904985
# PAY_AMT5              11.127417
# PAY_AMT6              10.640727
# default_next_month     1.343504
# dtype: float64

# %% [markdown]
# ### 4. Data Visualization

# %%
defaulters=df[df['default_next_month']==1]
defaulters
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 13        14    70000.0    1          2         2   30      1      2      2
# 16        17    20000.0    1          1         2   24      0      0      2
# 21        22   120000.0    2          2         1   39     -1     -1     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29991  29992   210000.0    1          2         1   34      3      2      2
# 29994  29995    80000.0    1          2         2   34      2      2      2
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
# Ratio of credit card contracts that will default next month
defaulters.shape[0]/df.shape[0]
# Out:
# 0.2212

# %%
cats = ['SEX', 'EDUCATION',  'MARRIAGE']
for column in cats:
    plt.figure(figsize=(5,3))
    sns.countplot(x=defaulters[column],alpha=0.8)

# %%
plt.figure(figsize=(18,4))
sns.countplot(x=defaulters['AGE'],alpha=0.8)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='count'>

# %%
# HistPlot
plt.figure(figsize=(12,5))
sns.histplot(x='LIMIT_BAL',hue='default_next_month',data=df,kde=True,stat="density",alpha=0.5)
plt.legend(['Exited=0','Exited=1'])
plt.show()

# %%
df['LIMIT_BAL'].value_counts().iloc[:5]
# Out:
# 50000.0     3365
# 20000.0     1976
# 30000.0     1610
# 80000.0     1567
# 200000.0    1528
# Name: LIMIT_BAL, dtype: int64

# %% [markdown]
# Observations -
#
# - There are 30,000 distinct credit card clients.
# - The average value for the amount of credit card limit is 167,484. The standard deviation is unusually large, max value being 1M.
# - People who have default next month have their education level as mostly graduate school and university.
# - Most of these clients are either married or single (less frequent the other status).
# - There are 22.1% of credit card contracts that will default next month.
# - The distribution for age is left skewed; thus young people's credit card contracts default more as compared to older ones.
# - The largest number of credit cards are with limit of 50,000 (3365), followed by 20,000 (1976) and 30,000 (1610).

# %% [markdown]
# ### 5. Correlation Analysis
#
#     if corr(x,y) is between -0.1 to +0.1 = bad correlation
#
#     if corr(x,y) is between +0.1 to +0.5 = good correlation
#
#     if corr(x,y) is between -0.1 to -0.5 = good correlation
#
#     if corr(x,y) > +0.5 = Very good correlation
#
#     if corr(x,y) < -0.5 = Very good correlation

# %%
# Create correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

plt.figure(figsize=(20,20))
sns.heatmap(corr,mask=mask,annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# The heatmat shows that features are correlated with each other (collinearity), such us like PAY_0,2,3,4,5,6 and BILL_AMT1,2,3,4,5,6. In those cases, the correlation is positive. Uncorrelated data are poentially more useful. Thus, for now let us consider these 3 features. [['PAY_0', 'BILL_AMT1', 'PAY_AMT1']] from 3 of the categories.

# %% [markdown]
# ### 6. Predictive Modelling - TAIWAN Credit Card Company

# %% [markdown]
# #### **Methodology – Decision Trees**
#
# Decision Trees (DTs) are a non-parametric supervised learning method used for classification and regression. The goal is to create a model that predicts the value of a target variable by learning simple decision rules inferred from the data features.
#
# Decision Tree is a very popular algorithm for classification problems because it is easy to interpret and understand. An internal node represents a feature, the branch represents a decision rule, and each leaf node represents the outcome. Some advantages of decision trees are that they require less data preprocessing, i.e., no need to normalize features. However, noisy data can be easily overfitted and results in biased results when the data set is imbalanced.

# %% [markdown]
# #### Standardizing Features

# %%
y = df['default_next_month']
X= df[['PAY_0', 'BILL_AMT1', 'PAY_AMT1']]

# %%
X.shape
# Out:
# (30000, 3)

# %% [markdown]
# #### Standardizing features

# %%
from sklearn.preprocessing import StandardScaler
s=StandardScaler()
X_final=s.fit_transform(X)

# %%
X_final.shape
# Out:
# (30000, 3)

# %%
y.shape
# Out:
# (30000,)

# %% [markdown]
# #### Train test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_final,y, test_size=0.2, stratify=y, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (24000, 3)
# (6000, 3)
# (24000,)
# (6000,)

# %% [markdown]
# #### Finding the best hyperparameters using Randomized Search CV

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import RandomizedSearchCV,cross_val_score

# Setup the parameters and distributions to sample from: param_dist
param_dist = {"max_depth": [1,2,3,4,5,6,7,8,9],
              "max_features": [1,2,3],
              "min_samples_leaf": [1,2,3,4,5,6,7,8,9],
              "criterion": ["gini", "entropy"]}

# Instantiate a Decision Tree classifier: tree
tree = DecisionTreeClassifier()

# Instantiate the RandomizedSearchCV object: tree_cv
tree_cv = RandomizedSearchCV(tree, param_distributions=param_dist, cv=5, random_state=0)

# Fit it to the data
tree_cv.fit(X_train, y_train)

# Print the tuned parameters and score
print("Tuned Decision Tree Parameters: {}".format(tree_cv.best_params_))
# Out:
# Tuned Decision Tree Parameters: {'min_samples_leaf': 4, 'max_features': 3, 'max_depth': 1, 'criterion': 'gini'}

# %%
params=tree_cv.best_params_

# %% [markdown]
# ### 7. Model Fitting

# %%
# Create and fit a model with the parameters created in previous step

from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report

Tree = DecisionTreeClassifier(criterion= params['criterion'], max_depth= params['max_depth'], 
                                     max_features= params['max_features'], min_samples_leaf= params['min_samples_leaf'], 
                                     random_state=0)
Tree.fit(X_train, y_train)
y_pred = Tree.predict(X_test)

# %%
plt.figure(figsize=(15,10))
out = plot_tree(Tree,filled=True)
for o in out:
    arrow = o.arrow_patch
    if arrow is not None:
        arrow.set_edgecolor('black')
        arrow.set_linewidth(2)

# %% [markdown]
# ### 8. Model Evaluation

# %% [markdown]
# #### Performing 5 fold cross validation

# %%
## 5-fold cross-validation 
cv_scores =cross_val_score(Tree, X_train, y_train, cv=5)
print("CV Scores",cv_scores)
# Out:
# CV Scores [0.81916667 0.82375    0.81958333 0.819375   0.81666667]

# %%
print("Average 5-Fold CV Score: {}".format(round(np.mean(cv_scores),4)), 
      ", Standard deviation: {}".format(round(np.std(cv_scores),4)))
# Out:
# Average 5-Fold CV Score: 0.8197 , Standard deviation: 0.0023

# %%
# Find the accuracy score and print classification report

print('Accuracy:', accuracy_score(y_pred,y_test))

print(classification_report(y_test, y_pred))

plt.figure(figsize=(4,3))
ConfMatrix = confusion_matrix(y_test,Tree.predict(X_test))
sns.heatmap(ConfMatrix,annot=True, cmap="Blues", fmt="d", 
            xticklabels = ['Non-default', 'Default'], 
            yticklabels = ['Non-default', 'Default'])
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title("Confusion Matrix - Decision Tree");
# Out:
# Accuracy: 0.8191666666666667
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89      4673
#            1       0.69      0.33      0.45      1327
#
#     accuracy                           0.82      6000
#    macro avg       0.76      0.64      0.67      6000
# weighted avg       0.80      0.82      0.79      6000

# %% [markdown]
# ### 9. Export the model for deployment

# %%
# Export model
import joblib
joblib.dump(Tree,"model.pkl")
# Out:
# ['model.pkl']
